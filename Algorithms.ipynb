# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

df = pd.read_excel("nursery.xlsx")
print (df.columns)
#print (df.head(2))

df.dtypes

df_1 = pd.DataFrame()

label = LabelEncoder()

#sample_list = ['a','b','b','a']
#new_list = label.fit_transform(sample_list)
#print (new_list)

cols = df.columns.tolist()
#print (type(cols))

for column in cols:
    df_1[column] = label.fit_transform(df[column].astype('str'))

    print(df_1)
    
from sklearn.metrics import accuracy_score

#classifier on the training dataset

#building a decision tree classifier
decision_clf = DecisionTreeClassifier()
decision_clf = decision_clf.fit(X_train,Y_train)

decision_predict = decision_clf.predict(X_test)

print(accuracy_score(Y_test,decision_predict))

#10-fold cross validation 

decision_clf1 = DecisionTreeClassifier()
#decision_clf1 = DecisionTreeClassifier(max_depth = 10) ---> using max_depth we can define the depth of the tree
#decision_clf1 = decision_clf.fit(X_train,Y_train)

cross_val_score(decision_clf1,X_train,Y_train,cv=10)

# using the classifier on the entire dataset

decision_clf2 = DecisionTreeClassifier()
decision_clf2 = decision_clf.fit(X,Y)

cross_val_score(decision_clf2,X,Y,cv=10)

from sklearn.naive_bayes import MultinomialNB

naive_clf1 = MultinomialNB()
naive_clf1 = naive_clf1.fit(X_train,Y_train)

#decision_clf1 = DecisionTreeClassifier(max_depth = 10) ---> using max_depth we can define the depth of the tree
#decision_clf1 = decision_clf.fit(X_train,Y_train)

cross_val_score(naive_clf1,X_train,Y_train,cv=10)

from sklearn.naive_bayes import GaussianNB

naive_clf2 = GaussianNB()
naive_clf2 = naive_clf2.fit(X_train,Y_train)

cross_val_score(naive_clf2,X_train,Y_train,cv=10)
